# %%
import pandas as pd
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("https://raw.githack.com/albert6051/CSc59969_Final_Project_data/master/task7.csv")

# %%
new_data = data.drop(['vehicle_id', 'total_time', 'moving_time'], axis=1)

# %%
scatter_matrix(new_data, alpha=0.2)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000028777038390>,
# ...
#       dtype=object)
